# %%
#Data Frames I
#DataFrames are 2D data structures

# %%
import pandas as pd

# %%
nba = pd.read_csv("nba.csv")
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
#shared methodes and attributes between series and dataframes
nba.head()
nba.head(n=2)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
#
#      College     Salary
# 0      Texas  7730337.0
# 1  Marquette  6796117.0

# %%
nba.index
# Out:
# RangeIndex(start=0, stop=458, step=1)

# %%
nba.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
nba.dtypes.value_counts()
# Out:
# object     5
# float64    4
# dtype: int64

# %%
nba.shape
#gives the dimension of dataframe
# Out:
# (458, 9)

# %%
nba.values
# Out:
# array([['Avery Bradley', 'Boston Celtics', 0.0, ..., 180.0, 'Texas',
#         7730337.0],
#        ['Jae Crowder', 'Boston Celtics', 99.0, ..., 235.0, 'Marquette',
#         6796117.0],
#        ['John Holland', 'Boston Celtics', 30.0, ..., 205.0,
#         'Boston University', nan],
#        ...,
#        ['Tibor Pleiss', 'Utah Jazz', 21.0, ..., 256.0, nan, 2900000.0],
#        ['Jeff Withey', 'Utah Jazz', 24.0, ..., 231.0, 'Kansas', 947276.0],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=object)

# %%
batdata = pd.read_csv("battery data1.csv")

# %%
nba.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
rev = pd.read_csv("revenue.csv", index_col = "Date")
rev.head(3)
# Out:
#         New York  Los Angeles  Miami
# Date
# 1/1/16       985          122    499
# 1/2/16       738          788    534
# 1/3/16        14           20    933

# %%
s = pd.Series([1,2,3,4,5])
s.sum()
# Out:
# 15

# %%
rev.sum(axis = "columns")
# Out:
# Date
# 1/1/16     1606
# 1/2/16     2060
# 1/3/16      967
# 1/4/16     2519
# 1/5/16      438
# 1/6/16     1935
# 1/7/16     1234
# 1/8/16     2313
# 1/9/16     2623
# 1/10/16     555
# dtype: int64

# %%
nba = pd.read_csv("nba.csv")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
#how to extract single column from a database
nba.Name
# Out:
# 0      Avery Bradley
# 1        Jae Crowder
# 2       John Holland
# 3        R.J. Hunter
# 4      Jonas Jerebko
#            ...
# 453     Shelvin Mack
# 454        Raul Neto
# 455     Tibor Pleiss
# 456      Jeff Withey
# 457              NaN
# Name: Name, Length: 458, dtype: object

# %%
#second way to extract column from dataframe
nba["Name"]
# Out:
# 0      Avery Bradley
# 1        Jae Crowder
# 2       John Holland
# 3        R.J. Hunter
# 4      Jonas Jerebko
#            ...
# 453     Shelvin Mack
# 454        Raul Neto
# 455     Tibor Pleiss
# 456      Jeff Withey
# 457              NaN
# Name: Name, Length: 458, dtype: object

# %%
type(nba["Name"])
# Out:
# pandas.core.series.Series

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
#to exteact multiple columns from dataframes - just put nested square brackets
nba[["Name","Position"]]
# Out:
#               Name Position
# 0    Avery Bradley       PG
# 1      Jae Crowder       SF
# 2     John Holland       SG
# 3      R.J. Hunter       SG
# 4    Jonas Jerebko       PF
# ..             ...      ...
# 453   Shelvin Mack       PG
# 454      Raul Neto       PG
# 455   Tibor Pleiss        C
# 456    Jeff Withey        C
# 457            NaN      NaN
#
# [458 rows x 2 columns]

# %%
type(nba[["Name","Position"]])
# Out:
# pandas.core.frame.DataFrame

# %%
list = ["Name", "Number"]
nba[list]
# Out:
#               Name  Number
# 0    Avery Bradley     0.0
# 1      Jae Crowder    99.0
# 2     John Holland    30.0
# 3      R.J. Hunter    28.0
# 4    Jonas Jerebko     8.0
# ..             ...     ...
# 453   Shelvin Mack     8.0
# 454      Raul Neto    25.0
# 455   Tibor Pleiss    21.0
# 456    Jeff Withey    24.0
# 457            NaN     NaN
#
# [458 rows x 2 columns]

# %%
#to add new column to data frame - its just like defining a new variable
nba["Sport"] = "Basketball"

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary       Sport
# 0              Texas  7730337.0  Basketball
# 1          Marquette  6796117.0  Basketball
# 2  Boston University        NaN  Basketball

# %%
nba["League"] = "National Basketball League"

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary       Sport                      League
# 0              Texas  7730337.0  Basketball  National Basketball League
# 1          Marquette  6796117.0  Basketball  National Basketball League
# 2  Boston University        NaN  Basketball  National Basketball League

# %%
#back to original dataframe
nba = pd.read_csv("nba.csv")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba.insert(3, column = "sport", value = "Basketball")
nba.head(3)
# Out:
#             Name            Team  Number       sport       Sport Position  \
# 0  Avery Bradley  Boston Celtics     0.0  Basketball  Basketball       PG
# 1    Jae Crowder  Boston Celtics    99.0  Basketball  Basketball       SF
# 2   John Holland  Boston Celtics    30.0  Basketball  Basketball       SG
#
#     Age Height  Weight            College     Salary
# 0  25.0    6-2   180.0              Texas  7730337.0
# 1  25.0    6-6   235.0          Marquette  6796117.0
# 2  27.0    6-5   205.0  Boston University        NaN

# %%
#broadcasting methods - done to make changes to a whole column 
nba.head(3)
# Out:
#             Name            Team  Number       sport       Sport Position  \
# 0  Avery Bradley  Boston Celtics     0.0  Basketball  Basketball       PG
# 1    Jae Crowder  Boston Celtics    99.0  Basketball  Basketball       SF
# 2   John Holland  Boston Celtics    30.0  Basketball  Basketball       SG
#
#     Age Height  Weight            College     Salary
# 0  25.0    6-2   180.0              Texas  7730337.0
# 1  25.0    6-6   235.0          Marquette  6796117.0
# 2  27.0    6-5   205.0  Boston University        NaN

# %%
nba["Age"].add(5) #or we can use
nba["Age"] + 5
# Out:
# 0      30.0
# 1      30.0
# 2      32.0
# 3      27.0
# 4      34.0
#        ...
# 453    31.0
# 454    29.0
# 455    31.0
# 456    31.0
# 457     NaN
# Name: Age, Length: 458, dtype: float64

# %%
nba["Salary"].sub(1000000)
# Out:
# 0      6730337.0
# 1      5796117.0
# 2            NaN
# 3       148640.0
# 4      4000000.0
#          ...
# 453    1433333.0
# 454    -100000.0
# 455    1900000.0
# 456     -52724.0
# 457          NaN
# Name: Salary, Length: 458, dtype: float64

# %%
#1 pond = 0.45kg and lets convery weight to pounds
nba["Weight in kg"] = nba["Weight"] * 0.45 # or we can use nba["Weight"].mul(0.45)
inplace=True

# %%
nba.head(3) #added the weight series in the dataframe
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary  Weight in kg
# 0              Texas  7730337.0         81.00
# 1          Marquette  6796117.0        105.75
# 2  Boston University        NaN         92.25

# %%
#display salary in million
nba["Salary in mill"] = nba["Salary"].div(1000000,inplace=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-141-e7534bc520a6> in <module>
#       1 #display salary in million
# ----> 2 nba["Salary in mill"] = nba["Salary"].div(1000000,inplace=False)
#
# TypeError: flex_wrapper() got an unexpected keyword argument 'inplace'

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary  Weight in kg  Salary in mill
# 0              Texas  7730337.0         81.00        7.730337
# 1          Marquette  6796117.0        105.75        6.796117
# 2  Boston University        NaN         92.25             NaN

# %%
nba["Position"].value_counts()
# Out:
# SG    102
# PF    100
# PG     92
# SF     85
# C      78
# Name: Position, dtype: int64

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary  Weight in kg  Salary in mill
# 0              Texas  7730337.0         81.00        7.730337
# 1          Marquette  6796117.0        105.75        6.796117
# 2  Boston University        NaN         92.25             NaN

# %%
nba.tail(3)
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary  Weight in kg  Salary in mill
# 455  2900000.0        115.20        2.900000
# 456   947276.0        103.95        0.947276
# 457        NaN           NaN             NaN

# %%
nba = pd.read_csv("nba.csv")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
#to drop dataframe rows - this one particularly for null values
nba.dropna()
#as visible, all naN values are deleted
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College     Salary
# 0            Texas  7730337.0
# ...

# %%
#how to fill naN values with our input
nba.fillna(999999)
# Out:
#               Name            Team    Number Position       Age  Height  \
# 0    Avery Bradley  Boston Celtics       0.0       PG      25.0     6-2
# 1      Jae Crowder  Boston Celtics      99.0       SF      25.0     6-6
# 2     John Holland  Boston Celtics      30.0       SG      27.0     6-5
# 3      R.J. Hunter  Boston Celtics      28.0       SG      22.0     6-5
# 4    Jonas Jerebko  Boston Celtics       8.0       PF      29.0    6-10
# ..             ...             ...       ...      ...       ...     ...
# 453   Shelvin Mack       Utah Jazz       8.0       PG      26.0     6-3
# 454      Raul Neto       Utah Jazz      25.0       PG      24.0     6-1
# 455   Tibor Pleiss       Utah Jazz      21.0        C      26.0     7-3
# 456    Jeff Withey       Utah Jazz      24.0        C      26.0     7-0
# 457         999999          999999  999999.0   999999  999999.0  999999
#
#        Weight            College     Salary  Salary in mill
# ...

# %%
nba["College"].fillna("No college", inplace = True)

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary  Salary in mill
# 0              Texas  7730337.0        7.730337
# 1          Marquette  6796117.0        6.796117
# 2  Boston University        NaN             NaN
# 3      Georgia State  1148640.0        1.148640
# 4         No college  5000000.0        5.000000

# %%
#.astype - to change dataframe column/row type and nAN values need to be dropped for this command to work, so --- ....
nba = pd.read_csv("nba.csv").dropna(how = "all")
nba.head(3)
nba["Salary"].fillna("0", inplace = True)
nba["College"].fillna("None", inplace = True)
nba.head(8)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University           0
# 3      Georgia State   1148640.0
# 4               None   5000000.0
# 5               None  12000000.0
# 6                LSU   1170960.0
# 7            Gonzaga   2165160.0

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 457 entries, 0 to 456
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   457 non-null    object
#  8   Salary    457 non-null    object
# dtypes: float64(3), object(6)
# memory usage: 35.7+ KB

# %%
nba["Salary"] = nba["Salary"].astype("int")

# %%
nba.head(4)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
#
#              College   Salary
# 0              Texas  7730337
# 1          Marquette  6796117
# 2  Boston University        0
# 3      Georgia State  1148640

# %%
#as we changed datatype from float to int, memory usgae decreases
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 457 entries, 0 to 456
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   457 non-null    object
#  8   Salary    457 non-null    int32
# dtypes: float64(3), int32(1), object(5)
# memory usage: 33.9+ KB

# %%
nba["Number"] = nba["Number"].astype(int)
nba["Age"] = nba["Age"].astype(int)

# %%
#again even lower memory usage
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 457 entries, 0 to 456
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    int32
#  3   Position  457 non-null    object
#  4   Age       457 non-null    int32
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   457 non-null    object
#  8   Salary    457 non-null    int32
# dtypes: float64(1), int32(3), object(5)
# memory usage: 30.3+ KB

# %%
#unique object creation - category datatype in jupyter
nba["Position"].nunique()
# Out:
# 5

# %%
nba["Position"] = nba["Position"].astype("category")

# %%
nba["Team"].nunique()
# Out:
# 30

# %%
#applying catergory data type on teams
nba["Team"] = nba["Team"].astype("category")

# %%
#even more memory saved
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 457 entries, 0 to 456
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    category
#  2   Number    457 non-null    int32
#  3   Position  457 non-null    category
#  4   Age       457 non-null    int32
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   457 non-null    object
#  8   Salary    457 non-null    int32
# dtypes: category(2), float64(1), int32(3), object(3)
# memory usage: 25.6+ KB

# %%
#sort a dataframe
nba.sort_values("Salary")
# Out:
#                 Name                 Team  Number Position  Age Height  \
# 397     Axel Toupane       Denver Nuggets       6       SG   23    6-7
# 350    Briante Weber           Miami Heat      12       PG   23    6-2
# 2       John Holland       Boston Celtics      30       SG   27    6-5
# 171    Dahntay Jones  Cleveland Cavaliers      30       SG   35    6-6
# 270   Xavier Munford    Memphis Grizzlies      14       PG   24    6-3
# ..               ...                  ...     ...      ...  ...    ...
# 339       Chris Bosh           Miami Heat       1       PF   32   6-11
# 251    Dwight Howard      Houston Rockets      12        C   30   6-11
# 33   Carmelo Anthony      New York Knicks       7       SF   32    6-8
# 169     LeBron James  Cleveland Cavaliers      23       SF   31    6-8
# 109      Kobe Bryant   Los Angeles Lakers      24       SF   37    6-6
#
#      Weight                College    Salary
# 397   210.0                   None         0
# ...

# %%
nba.tail(3)
# Out:
#              Name       Team  Number Position  Age Height  Weight College  \
# 454     Raul Neto  Utah Jazz      25       PG   24    6-1   179.0    None
# 455  Tibor Pleiss  Utah Jazz      21        C   26    7-3   256.0    None
# 456   Jeff Withey  Utah Jazz      24        C   26    7-0   231.0  Kansas
#
#       Salary
# 454   900000
# 455  2900000
# 456   947276

# %%
nba.sort_values("Age", ascending = False)
# Out:
#                    Name                    Team  Number Position  Age Height  \
# 304        Andre Miller       San Antonio Spurs      24       PG   40    6-3
# 400       Kevin Garnett  Minnesota Timberwolves      21       PF   40   6-11
# 298          Tim Duncan       San Antonio Spurs      21        C   40   6-11
# 261        Vince Carter       Memphis Grizzlies      15       SG   39    6-6
# 102      Pablo Prigioni    Los Angeles Clippers       9       PG   39    6-3
# ..                  ...                     ...     ...      ...  ...    ...
# 40   Kristaps Porzingis         New York Knicks       6       PF   20    7-3
# 401          Tyus Jones  Minnesota Timberwolves       1       PG   20    6-2
# 60       Christian Wood      Philadelphia 76ers      35       PF   20   6-11
# 226       Rashad Vaughn         Milwaukee Bucks      20       SG   19    6-6
# 122        Devin Booker            Phoenix Suns       1       SG   19    6-6
#
#      Weight         College   Salary
# ...

# %%
#sorting in multiple columns
nba.sort_values(["Team","Name"]) #first dorted by team and then name
# Out:
#                 Name                Team  Number Position  Age Height  Weight  \
# 312       Al Horford       Atlanta Hawks      15        C   30   6-10   245.0
# 318  Dennis Schroder       Atlanta Hawks      17       PG   22    6-1   172.0
# 323      Jeff Teague       Atlanta Hawks       0       PG   27    6-2   186.0
# 309    Kent Bazemore       Atlanta Hawks      24       SF   26    6-5   201.0
# 311     Kirk Hinrich       Atlanta Hawks      12       SG   35    6-4   190.0
# ..               ...                 ...     ...      ...  ...    ...     ...
# 381  Marcus Thornton  Washington Wizards      15       SF   29    6-4   205.0
# 376  Markieff Morris  Washington Wizards       5       PF   26   6-10   245.0
# 375     Nene Hilario  Washington Wizards      42        C   33   6-11   250.0
# 378  Otto Porter Jr.  Washington Wizards      22       SF   23    6-8   198.0
# 379   Ramon Sessions  Washington Wizards       7       PG   30    6-3   190.0
#
#           College    Salary
# ...

# %%
#sorting by index
nba.head(3)
# Out:
#             Name            Team  Number Position  Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25    6-2   180.0
# 1    Jae Crowder  Boston Celtics      99       SF   25    6-6   235.0
# 2   John Holland  Boston Celtics      30       SG   27    6-5   205.0
#
#              College   Salary
# 0              Texas  7730337
# 1          Marquette  6796117
# 2  Boston University        0

# %%
nba.sort_values(["Name","Team","College"]) #just randomizing the data
# Out:
#                 Name                    Team  Number Position  Age Height  \
# 152     Aaron Brooks           Chicago Bulls       0       PG   31    6-0
# 356     Aaron Gordon           Orlando Magic       0       PF   20    6-9
# 328   Aaron Harrison       Charlotte Hornets       9       SG   21    6-6
# 404    Adreian Payne  Minnesota Timberwolves      33       PF   25   6-10
# 312       Al Horford           Atlanta Hawks      15        C   30   6-10
# ..               ...                     ...     ...      ...  ...    ...
# 386  Wilson Chandler          Denver Nuggets      21       SF   29    6-8
# 270   Xavier Munford       Memphis Grizzlies      14       PG   24    6-3
# 402      Zach LaVine  Minnesota Timberwolves       8       PG   21    6-5
# 271    Zach Randolph       Memphis Grizzlies      50       PF   34    6-9
# 237    Zaza Pachulia        Dallas Mavericks      27        C   32   6-11
#
#      Weight         College    Salary
# 152   161.0          Oregon   2250000
# ...

# %%
nba.sort_index(ascending = False)
# Out:
#               Name            Team  Number Position  Age Height  Weight  \
# 456    Jeff Withey       Utah Jazz      24        C   26    7-0   231.0
# 455   Tibor Pleiss       Utah Jazz      21        C   26    7-3   256.0
# 454      Raul Neto       Utah Jazz      25       PG   24    6-1   179.0
# 453   Shelvin Mack       Utah Jazz       8       PG   26    6-3   203.0
# 452     Trey Lyles       Utah Jazz      41       PF   20   6-10   234.0
# ..             ...             ...     ...      ...  ...    ...     ...
# 4    Jonas Jerebko  Boston Celtics       8       PF   29   6-10   231.0
# 3      R.J. Hunter  Boston Celtics      28       SG   22    6-5   185.0
# 2     John Holland  Boston Celtics      30       SG   27    6-5   205.0
# 1      Jae Crowder  Boston Celtics      99       SF   25    6-6   235.0
# 0    Avery Bradley  Boston Celtics       0       PG   25    6-2   180.0
#
#                College   Salary
# 456             Kansas   947276
# 455               None  2900000
# ...

# %%
#rank values with .rank method
# it needs all nan values to be gone
nba.dropna(how = "all")
nba["Salary"] = nba["Salary"].fillna(0).astype(int)
nba.head(3)
# Out:
#             Name            Team  Number Position  Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25    6-2   180.0
# 1    Jae Crowder  Boston Celtics      99       SF   25    6-6   235.0
# 2   John Holland  Boston Celtics      30       SG   27    6-5   205.0
#
#              College   Salary
# 0              Texas  7730337
# 1          Marquette  6796117
# 2  Boston University        0

# %%
nba["Salary Rank"] = nba["Salary"].rank(ascending = False).astype(int)

# %%
nba.head()
# Out:
#             Name            Team  Number Position  Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25    6-2   180.0
# 1    Jae Crowder  Boston Celtics      99       SF   25    6-6   235.0
# 2   John Holland  Boston Celtics      30       SG   27    6-5   205.0
# 3    R.J. Hunter  Boston Celtics      28       SG   22    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics       8       PF   29   6-10   231.0
#
#              College   Salary  Salary Rank
# 0              Texas  7730337           97
# 1          Marquette  6796117          110
# 2  Boston University        0          452
# 3      Georgia State  1148640          322
# 4               None  5000000          147

# %%
#checking the rank by sorting salary values in ascending order
nba.sort_values("Salary",ascending = False)
# Out:
#                 Name                    Team  Number Position  Age Height  \
# 109      Kobe Bryant      Los Angeles Lakers      24       SF   37    6-6
# 169     LeBron James     Cleveland Cavaliers      23       SF   31    6-8
# 33   Carmelo Anthony         New York Knicks       7       SF   32    6-8
# 251    Dwight Howard         Houston Rockets      12        C   30   6-11
# 339       Chris Bosh              Miami Heat       1       PF   32   6-11
# ..               ...                     ...     ...      ...  ...    ...
# 353    Dorell Wright              Miami Heat      11       SF   30    6-9
# 264    Jordan Farmar       Memphis Grizzlies       4       PG   29    6-2
# 409       Greg Smith  Minnesota Timberwolves       4       PF   25   6-10
# 273   Alex Stepheson       Memphis Grizzlies      35       PF   28   6-10
# 270   Xavier Munford       Memphis Grizzlies      14       PG   24    6-3
#
#      Weight       College    Salary  Salary Rank
# ...

# %%
#filtering dataframes - 
pd.read_csv("employees.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-192-37c39bcf57fe> in <module>
#       1 #filtering dataframes -
# ----> 2 pd.read_csv("employees.csv")
#
# ~\.conda\envs\pandas_playground\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
# ...
