# %%
import pandas as pd

# %%
jodh = pd.read_csv("Jodhpur_1MW_VC0_HourlyRes_With_MACRO.csv")
jodh

# %%
lcos = pd.read_csv("VRFB LCOS Model.csv")
lcos
# Out:
#      1 MW Solar Plant -Jodhpur              Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0          \nTime (Hourly) -->                   00:00      01:00      02:00
# 1                         Date  Production Values (kW)        NaN        NaN
# 2                   01-01-1990                       0          0          0
# 3                   02-01-1990                       0          0          0
# 4                   03-01-1990                       0          0          0
# ..                         ...                     ...        ...        ...
# 391  % contribution from Solar                  91.37%        NaN        NaN
# 392                        NaN                     NaN        NaN        NaN
# 393             LCOE - Blended             4.338949183        NaN        NaN
# 394                        NaN                     NaN        NaN        NaN
# 395                        NaN                     NaN        NaN        NaN
#
# ...

# %%
lcos.loc[[2,3]]
# Out:
#   1 MW Solar Plant -Jodhpur Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 2                01-01-1990          0          0          0          0
# 3                02-01-1990          0          0          0          0
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 359  \
# 2          0          0          0          0          0  ...          NaN
# 3          0          0          0          0          0  ...          NaN
#
#   Unnamed: 360 Unnamed: 361 Unnamed: 362 Unnamed: 363 Unnamed: 364  \
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
#
#   Unnamed: 365 Unnamed: 366 Unnamed: 367 Unnamed: 368
# 2          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN
#
# [2 rows x 369 columns]

# %%
lcos.iloc[2,3]
# Out:
# '0'
